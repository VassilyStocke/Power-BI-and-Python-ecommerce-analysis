# %%
#rename the file df and import data via pandas read csv 
import pandas as pd
import numpy as np
df=pd.read_csv('df.csv')
df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# ...

# %%
#Check for duplicates
df[df.duplicated(subset=['order_id'], keep=False)]
# Out:
#                                 order_id  payment_sequential payment_type  \
# 25      5cfd514482e22bc992e7693f0e3e8df7                   2      voucher
# 35      b2bb080b6bc860118a246fd9b6fad6da                   1  credit_card
# 75      3689194c14ad4e2e7361ebd1df0e77b0                   2      voucher
# 84      723e462ce1ee50e024887c0b403130f3                   1  credit_card
# 102     21b8b46679ea6482cbf911d960490048                   2      voucher
# ...                                  ...                 ...          ...
# 103778  fd86c80924b4be8fb7f58c4ecc680dae                   1  credit_card
# 103817  6d4616de4341417e17978fe57aec1c46                   1  credit_card
# 103860  31bc09fdbd701a7a4f9b55b5955b8687                   6      voucher
# 103869  c9b01bef18eb84888f0fd071b8413b38                   1  credit_card
# 103874  d41f1036712e18ee525939d08b7a1c98                   1  credit_card
#
#         payment_installments  payment_value
# ...

# %%
#Check for outlier
import seaborn as sns
sns.boxplot(data=df[['payment_installments','payment_sequential']], orient='h')
# Out:
# <Axes: >

# %%
#issue with shipping_limit_dat
df[df['payment_value'] == 0]
# Out:
#                                 order_id  payment_sequential payment_type  \
# 19922   8bcbe01d44d147f901cd3192671144db                   4      voucher
# 36822   fa65dad1b0e818e3ccc5cb0e39231352                  14      voucher
# 43744   6ccb433e00daae1283ccc956189c82ae                   4      voucher
# 51280   4637ca194b6387e2d538dc89b124b0ee                   1  not_defined
# 57411   00b1cb0320190ca0daa2c88b35206009                   1  not_defined
# 62674   45ed6e85398a87c253db47c2d9f48216                   3      voucher
# 77885   fa65dad1b0e818e3ccc5cb0e39231352                  13      voucher
# 94427   c8c528189310eaa44a745b8d9d26908b                   1  not_defined
# 100766  b23878b3e8eb4d25a158f57d96331b18                   4      voucher
#
#         payment_installments  payment_value
# 19922                      1            0.0
# 36822                      1            0.0
# 43744                      1            0.0
# 51280                      1            0.0
# ...

# %%
# keep rows where 'payment' is not equals to  0
df = df[df['payment_value'] != 0]

# %%
df[df['order_id'] == 'fa65dad1b0e818e3ccc5cb0e39231352']
# Out:
#                                 order_id  payment_sequential payment_type  \
# 4885    fa65dad1b0e818e3ccc5cb0e39231352                  27      voucher
# 9985    fa65dad1b0e818e3ccc5cb0e39231352                   4      voucher
# 14321   fa65dad1b0e818e3ccc5cb0e39231352                   1      voucher
# 17274   fa65dad1b0e818e3ccc5cb0e39231352                   9      voucher
# 19565   fa65dad1b0e818e3ccc5cb0e39231352                  10      voucher
# 23074   fa65dad1b0e818e3ccc5cb0e39231352                   2      voucher
# 24879   fa65dad1b0e818e3ccc5cb0e39231352                  25      voucher
# 28330   fa65dad1b0e818e3ccc5cb0e39231352                   5      voucher
# 29648   fa65dad1b0e818e3ccc5cb0e39231352                   6      voucher
# 32519   fa65dad1b0e818e3ccc5cb0e39231352                  11      voucher
# 39108   fa65dad1b0e818e3ccc5cb0e39231352                  29      voucher
# 39111   fa65dad1b0e818e3ccc5cb0e39231352                  28      voucher
# ...

# %%
#Check number of payment sequential
df[df['order_id'] == 'fa65dad1b0e818e3ccc5cb0e39231352'].nunique()
# Out:
# order_id                 1
# payment_sequential      27
# payment_type             1
# payment_installments     1
# payment_value           24
# payment_seq              0
# dtype: int64

# %%
#change payment sequential
df.loc[df['order_id'] == 'fa65dad1b0e818e3ccc5cb0e39231352', 'payment_sequential'] = range(1, 28)

# %%
#Check value for payment type
print(df['payment_type'].unique())
# Out:
# ['credit_card' 'boleto' 'voucher' 'debit_card']

# %%
#Export the document
from google.colab import files
df.to_csv('paymentfinal.csv') 
files.download('paymentfinal.csv')
