# %%
#rename the file df and import data via pandas read csv 
import pandas as pd
import numpy as np
df=pd.read_csv('df.csv')

# %%
#Check the data type
df.dtypes
# Out:
# order_id                         object
# customer_id                      object
# order_status                     object
# order_purchase_timestamp         object
# order_approved_at                object
# order_delivered_carrier_date     object
# order_delivered_customer_date    object
# order_estimated_delivery_date    object
# dtype: object

# %%
#change into date time
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
df['order_approved_at']= pd.to_datetime(df['order_approved_at'])
df['order_delivered_carrier_date']= pd.to_datetime(df['order_delivered_carrier_date'])
df['order_delivered_customer_date']= pd.to_datetime(df['order_delivered_customer_date'])
df['order_estimated_delivery_date']= pd.to_datetime(df['order_estimated_delivery_date'])

# %%
df.dtypes
# Out:
# order_id                                 object
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
#Check for outlier
print(df['order_status'].unique())
print(df['order_purchase_timestamp'].min())
print(df['order_purchase_timestamp'].max())
print(df['order_approved_at'].min())
print(df['order_approved_at'].max())
print(df['order_delivered_carrier_date'].min())
print(df['order_delivered_carrier_date'].max())
print(df['order_delivered_customer_date'].min())
print(df['order_delivered_customer_date'].max())
print(df['order_estimated_delivery_date'].min())
print(df['order_estimated_delivery_date'].max())
# Out:
# ['delivered' 'invoiced' 'shipped' 'processing' 'unavailable' 'canceled'
#  'created' 'approved']
# 2016-09-04 21:15:19
# 2018-10-17 17:30:18
# 2016-09-15 12:16:38
# 2018-09-03 17:40:06
# 2016-10-08 10:34:01
# 2018-09-11 19:48:28
# 2016-10-11 13:46:32
# 2018-10-17 13:22:46
# 2016-09-30 00:00:00
# 2018-11-12 00:00:00

# %%
#Check for duplicate
df[df.duplicated(subset=['customer_id'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
df[df.duplicated(subset=['order_id'], keep=False)]
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_status, order_purchase_timestamp, order_approved_at, order_delivered_carrier_date, order_delivered_customer_date, order_estimated_delivery_date]
# Index: []

# %%
null_rows = df[df.isnull().any(axis=1)]

# print out the null rows
null_rows
# Out:
#                                order_id                       customer_id  \
# 6      136cce7faa42fdb2cefd53fdc79a6098  ed0271e0b7da060a393796590e7b737a
# 44     ee64d42b8cf066f35eac1cf57de1aa85  caded193e8e47b8362864762a83db3c5
# 103    0760a852e4e9d89eb77bf631eaaf1c84  d2a79636084590b7465af8ab374a8cf5
# 128    15bed8e2fec7fdbadb186b57c46c92f2  f3f0e613e0bdb9c7cee75504f0f90679
# 154    6942b8da583c2f9957e990d028607019  52006a9383bf149a4fb24226b173106f
# ...                                 ...                               ...
# 99283  3a3cddda5a7c27851bd96c3313412840  0b0d6095c5555fe083844281f6b093bb
# 99313  e9e64a17afa9653aacf2616d94c005b8  b4cd0522e632e481f8eaf766a2646e86
# 99347  a89abace0dcc01eeb267a9660b5ac126  2f0524a7b1b3845a1a57fcf3910c4333
# 99348  a69ba794cc7deb415c3e15a0a3877e69  726f0894b5becdf952ea537d5266e543
# 99415  5fabc81b6322c8443648e1b21a6fef21  32c9df889d41b0ee8309a5efb6855dcb
#
#       order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
df[df['order_id']== '13bdf405f961a6deec817d817f5c6624']
# Out:
#                                order_id                       customer_id  \
# 36034  13bdf405f961a6deec817d817f5c6624  b279a1d441c73c1974d7a63618855aa0
#
#       order_status order_purchase_timestamp   order_approved_at  \
# 36034     canceled      2017-03-16 02:30:51 2017-03-16 02:30:51
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 36034                          NaT                           NaT
#
#       order_estimated_delivery_date
# 36034                    2017-08-08
